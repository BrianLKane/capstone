# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
batters_2018_standard = pd.read_csv('../data/fangraphs/batters_2018_standard.csv')

# %%
batters_2018_standard.groupby('Team')['Name'].count()
# Out:
# Team
# Angels          5
# Astros          5
# Athletics       5
# Blue Jays       3
# Braves          6
# Brewers         6
# Cardinals       5
# Cubs            5
# Diamondbacks    5
# Dodgers         2
# Giants          4
# Indians         4
# Mariners        6
# Marlins         3
# Mets            3
# Nationals       2
# Orioles         3
# Padres          4
# Phillies        5
# Pirates         2
# Rangers         4
# Rays            2
# Red Sox         5
# Reds            5
# Rockies         4
# Royals          4
# Tigers          2
# Twins           5
# White Sox       5
# Yankees         3
# Name: Name, dtype: int64

# %%
batters_2018_standard[batters_2018_standard['Team']=='Cardinals']
# Out:
#                 Name       Team    G   AB   PA    H   1B  2B  3B  HR  ...  \
# 10     Jose Martinez  Cardinals  152  534  590  163  116  30   0  17  ...
# 25  Paul Goldschmidt  Cardinals  158  593  690  172   99  35   5  33  ...
# 35     Marcell Ozuna  Cardinals  148  582  628  163  122  16   2  23  ...
# 58     Yadier Molina  Cardinals  123  459  503  120   80  20   0  20  ...
# 64    Matt Carpenter  Cardinals  156  564  677  145   67  42   0  36  ...
#
#     IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG  playerid
# 10    0  104    2   3   2   15   0   3  0.305      7996
# 25   11  173    6   0   0    7   7   4  0.290      9218
# 35    2  110    3   4   0   10   3   0  0.280     10324
# 58    0   66    9   6   0   15   4   3  0.261      7007
# 64   17  158    6   4   0    0   4   1  0.257      8090
#
# [5 rows x 23 columns]

# %%
df2017 = pd.read_csv('../data/fangraphs/batters_2017_standard.csv')

# %%
df2017[df2017['Team'] == 'Cardinals']
# Out:
#                   Name       Team    G   AB   PA    H   1B  2B  3B  HR  ...  \
# 32       Marcell Ozuna  Cardinals  159  613  679  191  122  30   2  37  ...
# 34       Jose Martinez  Cardinals  106  272  307   84   56  13   1  14  ...
# 57    Paul Goldschmidt  Cardinals  155  558  665  166   93  34   3  36  ...
# 87         Paul DeJong  Cardinals  108  417  443  119   67  26   1  25  ...
# 88         Kolten Wong  Cardinals  108  354  411  101   67  27   3   4  ...
# 119      Yadier Molina  Cardinals  136  501  543  137   91  27   1  18  ...
# 127        Jedd Gyorko  Cardinals  125  426  481  116   73  21   2  20  ...
# 161      Dexter Fowler  Cardinals  118  420  491  111   62  22   9  18  ...
# 168    Adam Wainwright  Cardinals   26   42   50   11    7   2   0   2  ...
# 252     Matt Carpenter  Cardinals  145  497  622  120   64  31   2  23  ...
# 284       Matt Wieters  Cardinals  123  422  465   95   65  20   0  10  ...
# ...

# %%
batters_2018_standard.head()
# Out:
#                Name     Team    G   AB   PA    H   1B  2B  3B  HR  ...  IBB  \
# 0      Mookie Betts  Red Sox  136  520  614  180   96  47   5  32  ...    8
# 1     J.D. Martinez  Red Sox  150  569  649  188  106  37   2  43  ...   11
# 2  Christian Yelich  Brewers  147  574  651  187  110  34   7  36  ...    2
# 3       Jose Altuve   Astros  137  534  599  169  125  29   2  13  ...    4
# 4        Mike Trout   Angels  140  471  608  147   80  24   4  39  ...   25
#
#     SO  HBP  SF  SH  GDP  SB  CS    AVG  playerid
# 0   91    8   5   0    5  30   6  0.346     13611
# 1  146    4   7   0   19   6   1  0.330      6184
# 2  135    7   2   0   14  22   4  0.326     11477
# 3   79    6   1   3   17  17   4  0.316      5417
# 4  124   10   4   0    5  24   2  0.312     10155
#
# [5 rows x 23 columns]

# %%
daily_2019 = pd.read_csv('../data/fangraphs/batters_2019_daily_standard.csv')

# %%
daily_2019.shape
# Out:
# (7701, 24)

# %%
daily_2019.head()
# Out:
#          Date              Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2019-03-20         Jay Bruce  SEA  1   5   4  1   1   0   0  ...    0   2
# 1  2019-03-20  Jurickson Profar  OAK  1   4   4  1   0   1   0  ...    0   1
# 2  2019-03-20      Omar Narvaez  SEA  1   4   3  0   0   0   0  ...    0   1
# 3  2019-03-20     Ichiro Suzuki  SEA  1   2   1  0   0   0   0  ...    0   0
# 4  2019-03-20  Daniel Vogelbach  SEA  1   1   0  0   0   0   0  ...    0   0
#
#    HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 0    1   0   0    0   0   0  0.25      9892
# 1    0   0   0    0   0   0  0.25     10815
# 2    0   0   0    0   0   0  0.00     13338
# 3    0   0   0    0   0   0  0.00      1101
# 4    1   0   0    0   0   0  0.00     14130
#
# [5 rows x 24 columns]

# %%
daily_2018_1 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard1.csv')
daily_2018_2 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard2.csv')
daily_2018_3 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard3.csv')
daily_2018_4 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard4.csv')
daily_2018_5 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard5.csv')

# %%
daily_2018_1.shape[0] + daily_2018_2.shape[0] + daily_2018_3.shape[0] + daily_2018_4.shape[0] + daily_2018_5.shape[0]
# Out:
# 53761

# %%
daily_2018_2.shape
# Out:
# (12833, 24)

# %%
daily_2018_3.shape
# Out:
# (14164, 24)

# %%
daily_2018_4.shape
# Out:
# (13136, 24)

# %%
daily_2018_5.shape
# Out:
# (4774, 24)

# %%
daily_2018_1.tail()
# Out:
#             Date                  Name   Tm  G  PA  AB  H  1B  2B  3B  ...  \
# 8849  2018-04-30  Nicholas Castellanos  DET  1   4   3  1   0   1   0  ...
# 8850  2018-04-30          Jorge Alfaro  PHI  1   4   4  2   1   0   0  ...
# 8851  2018-04-30             C.J. Cron  TBR  1   4   4  1   0   0   0  ...
# 8852  2018-04-30         Lewis Brinson  MIA  1   4   4  1   1   0   0  ...
# 8853  2018-04-30           Brad Miller  TBR  1   4   4  1   0   0   0  ...
#
#       IBB  SO  HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 8849    0   0    1   0   0    1   0   0  0.333333     11737
# 8850    0   1    0   0   0    0   0   0  0.500000     12180
# 8851    0   1    0   0   0    0   0   0  0.250000     12546
# 8852    0   1    0   0   0    0   0   0  0.250000     14352
# 8853    0   1    0   0   0    0   0   0  0.250000     12775
#
# [5 rows x 24 columns]

# %%
daily_2018_2.head()
# Out:
#          Date              Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2018-05-01     Pedro Alvarez  BAL  1   4   4  0   0   0   0  ...    0   1
# 1  2018-05-01  Ronald Acuna Jr.  ATL  1   5   5  2   1   1   0  ...    0   1
# 2  2018-05-01     Jace Peterson  BAL  1   4   4  0   0   0   0  ...    0   0
# 3  2018-05-01        Ryan Goins  KCR  1   2   2  1   1   0   0  ...    0   1
# 4  2018-05-01     Luis Valbuena  LAA  1   4   4  1   0   0   0  ...    0   0
#
#    HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 0    0   0   0    0   0   0  0.00      2495
# 1    0   0   0    0   0   0  0.40     18401
# 2    0   0   0    0   0   0  0.00     12325
# 3    0   0   0    0   0   0  0.50      9807
# 4    0   0   0    0   0   0  0.25      4969
#
# [5 rows x 24 columns]

# %%
daily_2018_2.tail()
# Out:
#              Date               Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  \
# 12828  2018-06-15       Jose Trevino  TEX  1   4   4  0   0   0   0  ...    0
# 12829  2018-06-15       Mallex Smith  TBR  1   4   3  1   1   0   0  ...    0
# 12830  2018-06-15      Gerardo Parra  COL  1   4   4  0   0   0   0  ...    0
# 12831  2018-06-15  Yangervis Solarte  TOR  1   4   4  3   0   1   0  ...    0
# 12832  2018-06-15      Matt Davidson  CHW  1   4   4  3   3   0   0  ...    0
#
#        SO  HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 12828   1    0   0   0    0   0   0  0.000000     16725
# 12829   1    0   0   0    0   0   0  0.333333     13608
# 12830   0    0   0   0    0   0   0  0.000000      8553
# 12831   0    0   0   0    0   0   0  0.750000      5352
# 12832   0    0   0   0    0   0   0  0.750000      7226
#
# [5 rows x 24 columns]

# %%
daily_2018_3.head()
# Out:
#          Date          Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  HBP  \
# 0  2018-06-09       Jon Jay  ARI  1   6   4  0   0   0   0  ...    0   2    2
# 1  2018-06-09  Gio Gonzalez  WSN  1   2   1  0   0   0   0  ...    0   1    0
# 2  2018-06-09  Craig Gentry  BAL  1   2   2  0   0   0   0  ...    0   0    0
# 3  2018-06-09    Max Stassi  HOU  1   4   3  1   0   0   0  ...    0   0    0
# 4  2018-06-09    Joey Votto  CIN  1   5   4  2   1   1   0  ...    0   1    0
#
#    SF  SH  GDP  SB  CS       AVG  playerId
# 0   0   0    0   0   0  0.000000      5227
# 1   0   1    0   0   0  0.000000      7448
# 2   0   0    0   0   0  0.000000      9571
# 3   0   0    0   0   0  0.333333     10059
# 4   0   0    0   0   0  0.500000      4314
#
# [5 rows x 24 columns]

# %%
daily_2018_3.tail()
# Out:
#              Date            Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  \
# 14159  2018-07-31   Michael Perez  TBR  1   4   4  1   0   1   0  ...    0
# 14160  2018-07-31  Willie Calhoun  TEX  1   3   2  1   1   0   0  ...    0
# 14161  2018-07-31    Yuli Gurriel  HOU  1   5   5  1   1   0   0  ...    0
# 14162  2018-07-31   Brandon Dixon  CIN  1   3   3  0   0   0   0  ...    0
# 14163  2018-07-31      Alex Avila  ARI  1   4   3  2   2   0   0  ...    0
#
#        SO  HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 14159   2    0   0   0    0   0   0  0.250000     12977
# 14160   0    0   0   0    0   0   0  0.500000     17838
# 14161   0    0   0   0    0   0   0  0.200000     19198
# 14162   2    0   0   0    0   0   0  0.000000     15214
# 14163   0    0   0   0    0   0   0  0.666667      7476
#
# [5 rows x 24 columns]

# %%
daily_2018_4.head()
# Out:
#          Date             Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2018-08-01  Spencer Kieboom  WSN  1   4   4  1   0   1   0  ...    0   1
# 1  2018-08-01     Caleb Joseph  BAL  1   4   3  1   1   0   0  ...    0   1
# 2  2018-08-01      Jeff McNeil  NYM  1   1   1  0   0   0   0  ...    0   1
# 3  2018-08-01      Tim Beckham  BAL  1   5   5  1   1   0   0  ...    0   3
# 4  2018-08-01      Trea Turner  WSN  1   4   4  1   0   1   0  ...    0   0
#
#    HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 0    0   0   0    0   0   0  0.250000     13300
# 1    0   0   0    0   0   0  0.333333      7087
# 2    0   0   0    0   0   0  0.000000     15362
# 3    0   0   0    0   0   0  0.200000      7949
# 4    0   0   0    0   2   0  0.250000     16252
#
# [5 rows x 24 columns]

# %%
daily_2018_4.tail()
# Out:
#              Date               Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  \
# 13131  2018-09-15          Wil Myers  SDP  1   5   4  1   0   1   0  ...    0
# 13132  2018-09-15     Ramon Laureano  OAK  1   4   3  1   1   0   0  ...    0
# 13133  2018-09-15  Adalberto Mondesi  KCR  1   5   5  1   1   0   0  ...    0
# 13134  2018-09-15         Adam Engel  CHW  1   3   3  2   2   0   0  ...    0
# 13135  2018-09-15   Delino DeShields  TEX  1   5   4  1   1   0   0  ...    0
#
#        SO  HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 13131   0    0   0   0    0   0   0  0.250000     10047
# 13132   2    0   0   0    0   0   0  0.333333     17128
# 13133   1    0   0   0    0   1   0  0.200000     13769
# 13134   0    0   0   0    0   0   2  0.666667     15082
# 13135   1    0   0   0    0   0   0  0.250000     11379
#
# [5 rows x 24 columns]

# %%
daily_2018_5.head()
# Out:
#          Date            Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2018-09-16  Scott Schebler  CIN  1   5   5  1   0   0   0  ...    0   2
# 1  2018-09-16     Yairo Munoz  STL  1   4   4  0   0   0   0  ...    0   2
# 2  2018-09-16    Nick Hundley  SFG  1   1   1  0   0   0   0  ...    0   1
# 3  2018-09-16      Max Kepler  MIN  1   5   4  1   0   0   0  ...    0   0
# 4  2018-09-16     Javier Baez  CHC  1   1   1  0   0   0   0  ...    0   0
#
#    HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 0    0   0   0    0   0   0  0.20     12225
# 1    0   0   0    0   0   0  0.00     16313
# 2    0   0   0    0   0   0  0.00      3376
# 3    0   0   0    0   0   0  0.25     12144
# 4    0   0   0    0   0   0  0.00     12979
#
# [5 rows x 24 columns]

# %%
daily_2018_5.tail()
# Out:
#             Date             Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  \
# 4769  2018-10-01  Tommy La Stella  CHC  1   1   1  0   0   0   0  ...    0
# 4770  2018-10-01    Orlando Arcia  MIL  1   4   4  4   4   0   0  ...    0
# 4771  2018-10-01      Kris Bryant  CHC  1   3   2  0   0   0   0  ...    0
# 4772  2018-10-01     Lorenzo Cain  MIL  1   4   4  1   1   0   0  ...    0
# 4773  2018-10-01         Ian Happ  CHC  1   1   0  0   0   0   0  ...    0
#
#       SO  HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 4769   0    0   0   0    0   0   0  0.00     12371
# 4770   0    0   0   0    0   0   0  1.00     13185
# 4771   1    0   0   0    0   0   0  0.00     15429
# 4772   0    0   0   0    0   0   0  0.25      9077
# 4773   0    0   0   0    0   0   0  0.00     17919
#
# [5 rows x 24 columns]

# %%
daily_2018 = daily_2018_1.append(daily_2018_2)

# %%
daily_2018 = daily_2018.append(daily_2018_3)

# %%
daily_2018 = daily_2018.append(daily_2018_4)
daily_2018 = daily_2018.append(daily_2018_5)

# %%
daily_2018.shape
# Out:
# (53761, 24)

# %%
# daily_2018.to_csv('../data/fangraphs/batters_2018_daily_standard.csv')

# %%
daily_2018 = pd.read_csv('../data/fangraphs/batters_2018_daily_standard.csv')
daily_2018.drop(columns='Unnamed: 0', inplace=True)

# %%
daily_2018.shape
# Out:
# (53761, 24)

# %%
daily_2018.head()
# Out:
#          Date             Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2018-03-29     Ryan LaMarre  MIN  1   1   1  1   1   0   0  ...    0   0
# 1  2018-03-29  Marwin Gonzalez  HOU  1   4   3  1   1   0   0  ...    0   1
# 2  2018-03-29    Manny Machado  BAL  1   5   4  2   1   1   0  ...    0   1
# 3  2018-03-29    Deven Marrero  ARI  1   1   1  1   1   0   0  ...    0   0
# 4  2018-03-29      Evan Gattis  HOU  1   4   3  0   0   0   0  ...    0   2
#
#    HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 0    0   0   0    0   0   0  1.000000     10700
# 1    0   0   0    1   0   0  0.333333      5497
# 2    0   0   0    0   1   0  0.500000     11493
# 3    0   0   0    0   0   0  1.000000     13325
# 4    0   0   0    0   0   0  0.000000     11003
#
# [5 rows x 24 columns]

# %%
batters_2018_standard = pd.read_csv('../data/fangraphs/batters_2018_standard.csv')

# %%
batters_2018_standard.shape
# Out:
# (251, 23)

# %%
batters_2018_standard.Team.value_counts()
# Out:
# Cardinals       12
# Brewers         12
# Astros          11
# Red Sox         10
# Twins           10
# Giants          10
# Cubs             9
# White Sox        9
# Athletics        9
# Braves           9
# Phillies         9
# Royals           9
# Rangers          9
# Reds             9
# Padres           9
# Nationals        8
# Mariners         8
# Angels           8
# Dodgers          8
# Pirates          8
# Indians          8
# Marlins          7
# Diamondbacks     7
# Yankees          7
# Rays             7
# Blue Jays        6
# Tigers           6
# Rockies          6
# Mets             6
# Orioles          5
# Name: Team, dtype: int64

# %%
batters_2018_advanced = pd.read_csv('../data/fangraphs/batters_2018_advanced.csv')

# %%
batters_2018_advanced.shape
# Out:
# (251, 21)

# %%
batters_2018.head()
# Out:
#                Name     Team    G   AB   PA    H   1B  2B  3B  HR  ...  IBB  \
# 0      Mookie Betts  Red Sox  136  520  614  180   96  47   5  32  ...    8
# 1     J.D. Martinez  Red Sox  150  569  649  188  106  37   2  43  ...   11
# 2  Christian Yelich  Brewers  147  574  651  187  110  34   7  36  ...    2
# 3       Jose Altuve   Astros  137  534  599  169  125  29   2  13  ...    4
# 4     Justin Turner  Dodgers  103  365  426  114   68  31   1  14  ...    3
#
#     SO  HBP  SF  SH  GDP  SB  CS    AVG  playerid
# 0   91    8   5   0    5  30   6  0.346     13611
# 1  146    4   7   0   19   6   1  0.330      6184
# 2  135    7   2   0   14  22   4  0.326     11477
# 3   79    6   1   3   17  17   4  0.316      5417
# 4   54   12   2   0   10   2   1  0.312      5235
#
# [5 rows x 23 columns]

# %%
batters_2018 = pd.DataFrame(pd.merge(batters_2018_standard, batters_2018_advanced, on='Name'))

# %%
batters_2018.shape
# Out:
# (251, 43)

# %%
batters_2018.head
# Out:
# <bound method NDFrame.head of                      Name        Team_x    G   AB  PA_x    H   1B  2B  3B  HR  \
# 0            Mookie Betts       Red Sox  136  520   614  180   96  47   5  32
# 1           J.D. Martinez       Red Sox  150  569   649  188  106  37   2  43
# 2        Christian Yelich       Brewers  147  574   651  187  110  34   7  36
# 3             Jose Altuve        Astros  137  534   599  169  125  29   2  13
# 4           Justin Turner       Dodgers  103  365   426  114   68  31   1  14
# 5              Mike Trout        Angels  140  471   608  147   80  24   4  39
# 6         Freddie Freeman        Braves  162  618   707  191  120  44   4  23
# 7        Michael Brantley        Astros  143  570   631  176  121  36   2  17
# 8            Lorenzo Cain       Brewers  141  539   620  166  129  25   2  10
# 9            Wilson Ramos          Mets  111  382   416  117   79  22   1  15
# 10            Ben Zobrist          Cubs  139  455   520  139   99  28   3   9
# ...

# %%
batters_2018.columns
# Out:
# Index(['Name', 'Team_x', 'G', 'AB', 'PA_x', 'H', '1B', '2B', '3B', 'HR', 'R',
#        'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'AVG_x',
#        'playerid_x', 'Team_y', 'PA_y', 'BB%', 'K%', 'BB/K', 'AVG_y', 'OBP',
#        'SLG', 'OPS', 'ISO', 'Spd', 'BABIP', 'UBR', 'wGDP', 'wSB', 'wRC',
#        'wRAA', 'wOBA', 'wRC+', 'playerid_y'],
#       dtype='object')

# %%
pitchers_2019_daily_standard = pd.read_csv('../data/fangraphs/pitchers_2019_daily_standard.csv')

# %%
pitchers_2019_daily_standard.shape
# Out:
# (874, 21)

# %%
pitchers_2019_daily_standard.head()
# Out:
#          Date            Name   Tm   IP  TBF      ERA  H  2B  3B  R  ...  HR  \
# 0  2019-03-20  Marco Gonzales  SEA  6.0   25   4.5000  7   3   0  4  ...   2
# 1  2019-03-20      Mike Fiers  OAK  3.0   16  15.0000  4   0   0  5  ...   1
# 2  2019-03-21   Yusei Kikuchi  SEA  4.2   19   1.9286  4   0   0  2  ...   0
# 3  2019-03-21   Marco Estrada  OAK  5.0   21   5.4000  5   2   0  3  ...   2
# 4  2019-03-28  Jhoulys Chacin  MIL  5.1   21   5.0625  3   0   0  3  ...   2
#
#    BB  IBB  HBP  SO       AVG       OBP       SLG      wOBA  playerId
# 0   1    0    0   4  0.291667  0.320000  0.666667  0.404710     15467
# 1   2    0    1   3  0.307692  0.437500  0.538462  0.419960      7754
# 2   1    0    0   3  0.222222  0.263158  0.222222  0.220863     20633
# 3   0    0    1   1  0.250000  0.285714  0.650000  0.382744      1118
# 4   2    0    0   7  0.157895  0.238095  0.473684  0.296759      2608
#
# [5 rows x 21 columns]

# %%
batters_2019_daily_standard = pd.read_csv('../data/fangraphs/batters_2019_daily_standard.csv')

# %%
batters_2019_daily_standard.head()
# Out:
#          Date              Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2019-03-20  Jurickson Profar  OAK  1   4   4  1   0   1   0  ...    0   1
# 1  2019-03-20      Omar Narvaez  SEA  1   4   3  0   0   0   0  ...    0   1
# 2  2019-03-20     Ichiro Suzuki  SEA  1   2   1  0   0   0   0  ...    0   0
# 3  2019-03-20  Daniel Vogelbach  SEA  1   1   0  0   0   0   0  ...    0   0
# 4  2019-03-20      Nick Hundley  OAK  1   2   2  0   0   0   0  ...    0   0
#
#    HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 0    0   0   0    0   0   0  0.25     10815
# 1    0   0   0    0   0   0  0.00     13338
# 2    0   0   0    0   0   0  0.00      1101
# 3    1   0   0    0   0   0  0.00     14130
# 4    0   0   0    2   0   0  0.00      3376
#
# [5 rows x 24 columns]

# %%
batters_2019_daily_standard.shape
# Out:
# (9260, 24)

# %%
batters_2019_daily_standard[batters_2019_daily_standard['Name'] == 'Mike Trout']
# Out:
#             Date        Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 218   2019-03-28  Mike Trout  LAA  1   4   3  1   1   0   0  ...    0   0
# 437   2019-03-29  Mike Trout  LAA  1   5   4  2   1   1   0  ...    1   0
# 654   2019-03-30  Mike Trout  LAA  1   4   3  1   0   1   0  ...    0   0
# 1068  2019-03-31  Mike Trout  LAA  1   4   2  0   0   0   0  ...    0   1
# 1329  2019-04-01  Mike Trout  LAA  1   4   2  0   0   0   0  ...    1   0
# 1496  2019-04-02  Mike Trout  LAA  1   4   3  1   1   0   0  ...    0   0
# 2099  2019-04-04  Mike Trout  LAA  1   4   3  2   1   0   0  ...    0   1
# 2350  2019-04-05  Mike Trout  LAA  1   4   4  2   0   0   0  ...    0   0
# 2395  2019-04-06  Mike Trout  LAA  1   5   2  1   0   0   0  ...    1   1
# 3022  2019-04-07  Mike Trout  LAA  1   5   2  1   0   0   0  ...    1   0
# 3100  2019-04-08  Mike Trout  LAA  1   4   2  0   0   0   0  ...    0   1
# 3418  2019-04-09  Mike Trout  LAA  1   2   2  2   2   0   0  ...    0   0
# ...

# %%
mike_trout_2019 = batters_2019_daily_standard[batters_2019_daily_standard['Name'] == 'Mike Trout']

# %%
mike_trout_2019.head()
# Out:
#             Date        Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 218   2019-03-28  Mike Trout  LAA  1   4   3  1   1   0   0  ...    0   0
# 437   2019-03-29  Mike Trout  LAA  1   5   4  2   1   1   0  ...    1   0
# 654   2019-03-30  Mike Trout  LAA  1   4   3  1   0   1   0  ...    0   0
# 1068  2019-03-31  Mike Trout  LAA  1   4   2  0   0   0   0  ...    0   1
# 1329  2019-04-01  Mike Trout  LAA  1   4   2  0   0   0   0  ...    1   0
#
#       HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 218     0   0   0    0   0   0  0.333333     10155
# 437     0   0   0    0   0   0  0.500000     10155
# 654     0   1   0    0   0   0  0.333333     10155
# 1068    1   0   0    0   1   0  0.000000     10155
# 1329    1   0   0    0   0   0  0.000000     10155
#
# [5 rows x 24 columns]

# %%
mike_trout_2019['Date'] = pd.to_datetime(mike_trout_2019['Date'])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mike_trout_2019.dtypes
# Out:
# Date        datetime64[ns]
# Name                object
# Tm                  object
# G                    int64
# PA                   int64
# AB                   int64
# H                    int64
# 1B                   int64
# 2B                   int64
# 3B                   int64
# HR                   int64
# R                    int64
# RBI                  int64
# BB                   int64
# IBB                  int64
# SO                   int64
# HBP                  int64
# SF                   int64
# SH                   int64
# GDP                  int64
# SB                   int64
# CS                   int64
# AVG                float64
# playerId             int64
# dtype: object

# %%
mike_trout_2019.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(16, 8))

plt.plot(mike_trout_2019['AVG'])
plt.title('Mike Trout - 2019 Daily Batting Average', fontsize=18);
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
trout_model = ARIMA(endog = mike_trout_2019['AVG'].diff(4).dropna(),
              order = (1,0,0))
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
arima = trout_model.fit()
preds = arima.predict()

# %%
preds.head()
# Out:
# Date
# 2019-04-01   -0.003848
# 2019-04-02    0.075715
# 2019-04-04    0.035469
# 2019-04-05   -0.085268
# 2019-04-06   -0.125514
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(mike_trout_2019['AVG'].diff(4), color = 'blue')
plt.plot(preds, color = 'orange')
plt.title(label = 'Mike Trout Daily AVG with ARIMA Predictions', fontsize=18)
plt.show();

# %%
batters_2019_daily_standard.tail()
# Out:
#             Date            Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 9255  2019-04-30       Ben Gamel  MIL  1   3   3  1   0   1   0  ...    0   1
# 9256  2019-04-30     Eric Thames  MIL  1   3   3  0   0   0   0  ...    0   0
# 9257  2019-04-30   Orlando Arcia  MIL  1   3   3  1   1   0   0  ...    0   0
# 9258  2019-04-30  Mike Moustakas  MIL  1   3   3  0   0   0   0  ...    0   0
# 9259  2019-04-30   Jorge Polanco  MIN  1   4   2  0   0   0   0  ...    0   2
#
#       HBP  SF  SH  GDP  SB  CS       AVG  playerId
# 9255    0   0   0    0   0   0  0.333333     12160
# 9256    0   0   0    0   0   0  0.000000      3711
# 9257    0   0   0    0   0   0  0.333333     13185
# 9258    0   0   0    0   0   0  0.000000      4892
# 9259    0   0   0    0   0   0  0.000000     13152
#
# [5 rows x 24 columns]

# %%
cardinals = batters_2019_daily_standard[batters_2019_daily_standard['Tm'] == 'STL']

# %%
cardinals.playerId.value_counts()
# Out:
# 9218     29
# 18015    29
# 12532    29
# 7996     29
# 8090     28
# 10324    27
# 7007     27
# 4062     26
# 18030    19
# 15711    19
# 10816    15
# 16313     8
# 4298      7
# 17479     6
# 16939     6
# 9803      6
# 2233      6
# 11761     5
# 14078     5
# 19206     5
# 14986     2
# 16110     1
# 13684     1
# 18138     1
# Name: playerId, dtype: int64

# %%
cardinals[cardinals['playerId'] == 9218]
# Out:
#             Date              Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  \
# 58    2019-03-28  Paul Goldschmidt  STL  1   4   3  0   0   0   0  ...    0
# 411   2019-03-29  Paul Goldschmidt  STL  1   6   5  4   1   0   0  ...    1
# 543   2019-03-30  Paul Goldschmidt  STL  1   4   4  1   1   0   0  ...    0
# 854   2019-03-31  Paul Goldschmidt  STL  1   4   4  1   0   0   0  ...    0
# 1208  2019-04-01  Paul Goldschmidt  STL  1   6   4  0   0   0   0  ...    0
# 1705  2019-04-03  Paul Goldschmidt  STL  1   5   4  0   0   0   0  ...    0
# 2224  2019-04-05  Paul Goldschmidt  STL  1   4   3  1   0   0   0  ...    0
# 2525  2019-04-06  Paul Goldschmidt  STL  1   5   5  0   0   0   0  ...    0
# 2820  2019-04-07  Paul Goldschmidt  STL  1   4   3  0   0   0   0  ...    0
# 3128  2019-04-08  Paul Goldschmidt  STL  1   4   2  0   0   0   0  ...    0
# 3391  2019-04-09  Paul Goldschmidt  STL  1   4   4  1   0   0   0  ...    0
# ...

# %%
cardinals.columns
# Out:
# Index(['Date', 'Name', 'Tm', 'G', 'PA', 'AB', 'H', '1B', '2B', '3B', 'HR', 'R',
#        'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH', 'GDP', 'SB', 'CS', 'AVG',
#        'playerId'],
#       dtype='object')

# %%
drop_cols = ['Tm', 'G', 'AB', '1B', '2B', '3B', 'HR', 'R', 'RBI', 'SF', 'SH', 'GDP', 'SB', 'CS', 'AVG']

# %%
cardinals.drop(columns=drop_cols, inplace=True)

# %%
cardinals[cardinals['playerId'] == 9218]
# Out:
#             Date              Name  PA  H  BB  IBB  SO  HBP  playerId
# 58    2019-03-28  Paul Goldschmidt   4  0   1    0   3    0      9218
# 411   2019-03-29  Paul Goldschmidt   6  4   1    1   0    0      9218
# 543   2019-03-30  Paul Goldschmidt   4  1   0    0   2    0      9218
# 854   2019-03-31  Paul Goldschmidt   4  1   0    0   2    0      9218
# 1208  2019-04-01  Paul Goldschmidt   6  0   2    0   2    0      9218
# 1705  2019-04-03  Paul Goldschmidt   5  0   1    0   1    0      9218
# 2224  2019-04-05  Paul Goldschmidt   4  1   1    0   1    0      9218
# 2525  2019-04-06  Paul Goldschmidt   5  0   0    0   1    0      9218
# 2820  2019-04-07  Paul Goldschmidt   4  0   1    0   0    0      9218
# 3128  2019-04-08  Paul Goldschmidt   4  0   2    0   1    0      9218
# 3391  2019-04-09  Paul Goldschmidt   4  1   0    0   1    0      9218
# 3712  2019-04-10  Paul Goldschmidt   4  1   0    0   1    0      9218
# ...

# %%
cardinals[cardinals['playerId'] == 9218]
# Out:
#             Date              Name  PA  H  BB  IBB  SO  HBP  playerId
# 58    2019-03-28  Paul Goldschmidt   4  0   1    0   3    0      9218
# 411   2019-03-29  Paul Goldschmidt   6  4   1    1   0    0      9218
# 543   2019-03-30  Paul Goldschmidt   4  1   0    0   2    0      9218
# 854   2019-03-31  Paul Goldschmidt   4  1   0    0   2    0      9218
# 1208  2019-04-01  Paul Goldschmidt   6  0   2    0   2    0      9218
# 1705  2019-04-03  Paul Goldschmidt   5  0   1    0   1    0      9218
# 2224  2019-04-05  Paul Goldschmidt   4  1   1    0   1    0      9218
# 2525  2019-04-06  Paul Goldschmidt   5  0   0    0   1    0      9218
# 2820  2019-04-07  Paul Goldschmidt   4  0   1    0   0    0      9218
# 3128  2019-04-08  Paul Goldschmidt   4  0   2    0   1    0      9218
# 3391  2019-04-09  Paul Goldschmidt   4  1   0    0   1    0      9218
# 3712  2019-04-10  Paul Goldschmidt   4  1   0    0   1    0      9218
# ...

# %%
cardinals.dtypes
# Out:
# Date        object
# Name        object
# PA           int64
# H            int64
# BB           int64
# IBB          int64
# SO           int64
# HBP          int64
# playerId     int64
# dtype: object

# %%
cardinals.playerId.unique()
# Out:
# array([ 4062,  7007,  8090,  9218, 10324, 18015, 12532, 15711,  7996,
#         9803, 18030, 17479, 16313, 19206, 11761, 14078,  2233,  4298,
#        10816, 14986, 13684, 18138, 16939, 16110])

# %%
for player in cardinals.playerId.unique():

# %%
batters_2019_daily_standard.playerId.nunique()
# Out:
# 605

# %%
batters_2019_daily_standard.head(10)
# Out:
#          Date              Name   Tm  G  PA  AB  H  1B  2B  3B  ...  IBB  SO  \
# 0  2019-03-20  Jurickson Profar  OAK  1   4   4  1   0   1   0  ...    0   1
# 1  2019-03-20      Omar Narvaez  SEA  1   4   3  0   0   0   0  ...    0   1
# 2  2019-03-20     Ichiro Suzuki  SEA  1   2   1  0   0   0   0  ...    0   0
# 3  2019-03-20  Daniel Vogelbach  SEA  1   1   0  0   0   0   0  ...    0   0
# 4  2019-03-20      Nick Hundley  OAK  1   2   2  0   0   0   0  ...    0   0
# 5  2019-03-20        Matt Olson  OAK  1   4   3  0   0   0   0  ...    0   0
# 6  2019-03-20       Tim Beckham  SEA  1   4   3  3   2   0   0  ...    0   0
# 7  2019-03-20        Ryon Healy  SEA  1   4   4  1   0   1   0  ...    0   1
# 8  2019-03-20       Khris Davis  OAK  1   4   4  1   0   0   0  ...    0   0
# 9  2019-03-20    Ramon Laureano  OAK  1   5   5  0   0   0   0  ...    0   3
#
#    HBP  SF  SH  GDP  SB  CS   AVG  playerId
# 0    0   0   0    0   0   0  0.25     10815
# ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
custom_df = pd.DataFrame(columns=batters_2019_daily_standard.columns)

# %%
for player in batters_2019_daily_standard.playerId.unique():
    player_df = batters_2019_daily_standard[batters_2019_daily_standard['playerId'] == player]
    player_df['Date'] = pd.to_datetime(player_df['Date'])
    player_df.set_index('Date', inplace=True)
    
    player_df['prev3_avg'] = player_df.H.rolling(3).sum() / player_df.PA.rolling(3).sum()
    player_df['prev5_avg'] = player_df.H.rolling(5).sum() / player_df.PA.rolling(5).sum()
    player_df['next_game_hit'] = (player_df.H.shift(-1) != 0)
    print(player_df.head())
    custom_df.append(player_df)
# Out:
# /Users/BK/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
custom_df
# Out:
# Empty DataFrame
# Columns: [Date, Name, Tm, G, PA, AB, H, 1B, 2B, 3B, HR, R, RBI, BB, IBB, SO, HBP, SF, SH, GDP, SB, CS, AVG, playerId]
# Index: []
#
# [0 rows x 24 columns]

# %%
goldy_df = cardinals[cardinals['playerId'] == 9218]

# %%
goldy_df.head()
# Out:
#             Date              Name  PA  H  BB  IBB  SO  HBP  playerId
# 58    2019-03-28  Paul Goldschmidt   4  0   1    0   3    0      9218
# 411   2019-03-29  Paul Goldschmidt   6  4   1    1   0    0      9218
# 543   2019-03-30  Paul Goldschmidt   4  1   0    0   2    0      9218
# 854   2019-03-31  Paul Goldschmidt   4  1   0    0   2    0      9218
# 1208  2019-04-01  Paul Goldschmidt   6  0   2    0   2    0      9218

# %%
goldy_df['Date'] = pd.to_datetime(goldy_df['Date'])
goldy_df.set_index('Date', inplace=True)

goldy_df['prev3_avg'] = goldy_df.H.rolling(3).sum() / goldy_df.PA.rolling(3).sum()
goldy_df['prev5_avg'] = goldy_df.H.rolling(5).sum() / goldy_df.PA.rolling(5).sum()
goldy_df['next_game_hit'] = (goldy_df.H.shift(-1) != 0)

# %%
goldy_df.head()
# Out:
#                         Name  PA  H  BB  IBB  SO  HBP  playerId  prev3_avg  \
# Date
# 2019-03-28  Paul Goldschmidt   4  0   1    0   3    0      9218        NaN
# 2019-03-29  Paul Goldschmidt   6  4   1    1   0    0      9218        NaN
# 2019-03-30  Paul Goldschmidt   4  1   0    0   2    0      9218   0.357143
# 2019-03-31  Paul Goldschmidt   4  1   0    0   2    0      9218   0.428571
# 2019-04-01  Paul Goldschmidt   6  0   2    0   2    0      9218   0.142857
#
#             prev5_avg  next_game_hit
# Date
# 2019-03-28        NaN           True
# 2019-03-29        NaN           True
# 2019-03-30        NaN           True
# 2019-03-31        NaN          False
# 2019-04-01       0.25          False

# %%
goldy_df.loc[:]['next_game_hit'] = (goldy_df.H.shift(-1) != 0)

# %%
goldy_df
# Out:
#                         Name  PA  H  BB  IBB  SO  HBP  playerId
# Date
# 2019-03-28  Paul Goldschmidt   4  0   1    0   3    0      9218
# 2019-03-29  Paul Goldschmidt   6  4   1    1   0    0      9218
# 2019-03-30  Paul Goldschmidt   4  1   0    0   2    0      9218
# 2019-03-31  Paul Goldschmidt   4  1   0    0   2    0      9218
# 2019-04-01  Paul Goldschmidt   6  0   2    0   2    0      9218
# 2019-04-03  Paul Goldschmidt   5  0   1    0   1    0      9218
# 2019-04-05  Paul Goldschmidt   4  1   1    0   1    0      9218
# 2019-04-06  Paul Goldschmidt   5  0   0    0   1    0      9218
# 2019-04-07  Paul Goldschmidt   4  0   1    0   0    0      9218
# 2019-04-08  Paul Goldschmidt   4  0   2    0   1    0      9218
# 2019-04-09  Paul Goldschmidt   4  1   0    0   1    0      9218
# 2019-04-10  Paul Goldschmidt   4  1   0    0   1    0      9218
# 2019-04-11  Paul Goldschmidt   5  0   0    0   1    0      9218
# 2019-04-13  Paul Goldschmidt   5  2   0    0   2    0      9218
# ...

# %%
int(True)
# Out:
# 1
